# %%
x=0
while x<10:
  print("data")
  x+=1
# Out:
# data
# data
# data
# data
# data
# data
# data
# data
# data
# data

# %%
x=5
while x<10:
  print('yes',x)
  x+=1
# Out:
# yes 5
# yes 6
# yes 7
# yes 8
# yes 9

# %%
y=[40,20,80,50,30,60,90]

# %%
y
# Out:
# [40, 20, 80, 50, 30, 60, 90]

# %%
y*85
# Out:
# [40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
#  80,
#  50,
#  30,
#  60,
#  90,
#  40,
#  20,
# ...

# %%
for i in y:
    print(i)
# Out:
# 40
# 20
# 80
# 50
# 30
# 60
# 90

# %%
for t in y:
    print(t*85)
# Out:
# 3400
# 1700
# 6800
# 4250
# 2550
# 5100
# 7650

# %%
g=[]
for t in y:
    k=(t*5)+10
    g.append(k)
print(g)
# Out:
# [210, 110, 410, 260, 160, 310, 460]

# %%
num=[11,12,33,44,55,66]
num
# Out:
# [11, 12, 33, 44, 55, 66]

# %%
for i in num:
    if i%2==0:
        print("even",i)
    else:
        print("odd",i)
# Out:
# odd 11
# even 12
# odd 33
# even 44
# odd 55
# even 66

# %%
g=[]
h=[]
for i in num:
    if i%2==0:
        g.append(i)
    else:
        h.append(i)
print("even=",g)
print("odd=",h)
# Out:
# even= [12, 44, 66]
# odd= [11, 33, 55]

# %%
n=[31,45,66,33,90,78,67,87,89,93,25,59,9,81]

# %%
n
# Out:
# [31, 45, 66, 33, 90, 78, 67, 87, 89, 93, 25, 59, 9, 81]

# %%
h=[]
for i in n:
    a=str(i)
    b=a.replace('8','5')
    c=int(b)
    h.append(c)

# %%
h
# Out:
# [3, 1]

# %% [raw]
# x='software0'
# y=''
# for i in x:
# if i.lower() not in ('s'.'o'):
# y+=0
